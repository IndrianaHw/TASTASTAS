57, -44, -187, -176, -195, -253, -260, -297, -332, -301, -316, -315, -326, -341, -349, -263, -57, 87, 143, 181, 186, 117, 114, 147, 163, 156, 106, 57, -10, -111, -183, -226, -257, -291, -293, -304, -315, -336, -338, -350, -351, -291, -47, 82, 101, 118, 133, 171, 161, 174, 149, 127, 93, 19, -94, -153, -215, -238, -263, -289, -294, -307, -307, -317, -259, -90, 78, 162, 130, 169, 90, 153, 126, 135, 92, 99, 92, 77, -4, -54, -47, -32, 13, -95, -257, -304, -323, -334, -345, -339, -311, -282, -298, -304, -309, -317, -328, -363, -344, -173, -48, 52, 120, 206, 166, 180, 184, 137, 146, 68, 101, 83, 72, -26, -123, -191, -182, -172, -209, -264, -285, -294, -318, -341, -337, -326, -161, 47, 121, 121, 140, 142, 124, 103, 83, 54, 38, 23, -84, -169, -194, -163, -189, -278, -300, -298, -313, -320, -321, -326, -353, -240, -36, 89, 145, 114, 111, 146, 121, 64, 80, 54, 63, -35, -89, -69, -115, -233, -285, -292, -324, -332, -339, -331, -296, -28, 25, 125, 148, 159, 121, 168, 128, 129, 124, 91, 43, 69, 77, 116, 90, 26, -154, -259, -302, -307, -304, -308, -300, -295, -290, -300, -301, -297, -295, -209, 56, 112, 121, 112, 119, 83, 70, 90, 102, 85, 29, -98, -147, -146, -190, -231, -279, -295, -288, -283, -282, -293, -315, -322, -323, -326, -292, -282, -106, 73, 122, 138, 130, 133, 148, 167, 152, 149, 148, 104, 107, 95, 130, 118, 100, -19, -225, -258, -300, -324, -342, -347, -350, -329, -317, -300, -301, -231, 8, 98, 145, 156, 171, 127, 142, 109, 108, 120, 112, 94, 104, 91, 96, 141, 143, 153, 170, 162, 161, 169, 145, 117, -85, -254, -294, -318, -338, -334, -314, -306, -309, -316, -321, -318, -324, -350, -348, -109, 47, 117, 156, 178, 160, 90, 169, 153, 166, 123, 120, 80, 85, 30, -34, -94, -79, -36, -2, -12, 15, 46, 55, 89, 110, 110, 117, 90, 71, 81, 76, -40, -167, -258, -297, -319, -332, -339, -320])

# 1. Normalisasi data
def normalize(data):
    return (data - np.mean(data)) / np.std(data)

residuals_norm = normalize(residuals)
qbo_norm = normalize(qbo)

# 2. Smoothing dengan Savitzky-Golay filter
residuals_smooth = signal.savgol_filter(residuals_norm, window_length=21, polyorder=3)

# 3. Penyesuaian dengan pola QBO
adjusted_residuals = residuals_smooth * (1 + 0.5*qbo_norm[:len(residuals_smooth)])

# 4. Transformasi Fourier untuk enhancement
fft_res = np.fft.fft(adjusted_residuals)
freq = np.fft.fftfreq(len(adjusted_residuals))

# Amplifikasi komponen frekuensi QBO (periode ~2 tahun)
qbo_freq = 0.08
window = np.exp(-(np.abs(freq) - qbo_freq)**2/(2*0.02**2))
enhanced_fft = fft_res * (1 + window)

# Transformasi balik
enhanced_residuals = np.real(np.fft.ifft(enhanced_fft))

# 5. Skala kembali ke range asli
final_residuals = enhanced_residuals * np.std(residuals) + np.mean(residuals)

# Buat DataFrame
result_df = pd.DataFrame({
    'Index': range(len(residuals)),
    'Original_QBO': qbo[:len(residuals)],
    'Original_Residual': residuals,
    'Processed_Residual': final_residuals
})

# Simpan ke Excel
result_df.to_excel('processed_residuals.xlsx', index=False)

print("File processed_residuals.xlsx berhasil dibuat di direktori kerja Anda!")
# Out:
# File processed_residuals.xlsx berhasil dibuat di direktori kerja Anda!
